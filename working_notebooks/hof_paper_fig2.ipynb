# %% [markdown]
# # For Fig. 1 in the Hof. Butterfly MBS paper
#
# This figure will have three panels showing (1) the gap labelling in energy and its projection down onto the phase transition along $\mu$, this will have a colour-labelled key and an inset plot of a small QC gap section of mu zoomed in on the energy axis to show there is really degeneracy-breaking, this will take up the top half of the overall plot; (2) raw MP versus $\mu$ matchin x axes with a line to show the $\epsilon$ (MP tolerance) used; (3) the log plot of $\epsilon$ vs $\mu$ showing the acceptable range of $\epsilon$, (2) and (3) together take up the bottom half of the overall plot, they will all have matched $\mu$ axes and $\mu_c$ will be indicated along all.
